# %%
import tensorflow as tf
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

import gym
from gym import spaces
from gym.utils import seeding
from stable_baselines.common.env_checker import check_env
from stable_baselines import PPO2
from stable_baselines.common.policies import MlpPolicy

import numpy as np
from ads_utils import load_data, plot, Environment

from tqdm import tqdm

# %% [markdown]
# https://github.com/notadamking/Stock-Trading-Environment/blob/master/env/StockTradingEnv.py
# The code follows some of this implementation.

# %%
INITIAL_BALANCE = 10_000
PAST_TICKS = 5
        
'''NOTE: there is no train/test split yet'''            
data = load_data([2])

fake = np.linspace(100, 200, len(data))
data['close1'] = fake
fake = np.linspace(200, 100, len(data))
data['close2'] = fake
fake = 10*np.sin(np.linspace(0, 3141.592, len(data))/50) + 20
data['close3'] = fake
fake = 100*np.sin(np.linspace(0, 3141.592, len(data))/50) + np.random.normal(1000, 50, len(data))
data['close4'] = fake
fake = np.random.normal(1000, 50, len(data))
data['close5'] = fake
fake = 1000 - np.abs(np.arange(0, len(data)) - len(data)/2) * 0.05
data['close6'] = fake
fake = np.random.normal(1000, 50, len(data)) - np.abs(np.arange(0, len(data)) - len(data)/2) * 0.05
data['close7'] = fake

envs = []
for col in ['close'] + [f'close{i}' for i in range(1, 8)]:
    env = Environment(data[col].to_list(), balance=INITIAL_BALANCE, past_ticks=PAST_TICKS)
    envs.append(env)

# %%
# It will check your custom environment and output additional warnings if needed
#check_env(envs[0])

# %%
# WARNING, WILL TAKE 1.5HRS TO RUN, REDUCE TOTAL TIMESTEPS FROM 1_000_000 FOR QUICKER TRAINING
if 0:

    for env in tqdm(envs):
        env.reset()

        model = PPO2(MlpPolicy, env, verbose=1)

        model.learn(total_timesteps=1_000_000, log_interval=1e9) 

        state = env.reset()

        portfolio_values = []
        prices = []
        actions = []
        for i in range(10_000):
            action, _ = model.predict(state)

            price, portfolio_value = env.get_data()
            actions.append(action)
            prices.append(price)
            portfolio_values.append(portfolio_value)

            state, reward, done, _ = env.step(action)

            if done:
                break

        plot(prices, actions, portfolio_values, right_y_adjust=1.1)
# Out:
#   0%|                                                                                            | 0/8 [00:00<?, ?it/s]
# Wrapping the env in a DummyVecEnv.
# --------------------------------------
# | approxkl           | 7.149944e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000775     |
# | fps                | 354           |
# | n_updates          | 1             |
# | policy_entropy     | 1.0985152     |
# | policy_loss        | -0.0018132078 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 555.19183     |
# --------------------------------------
#  12%|██████████▏                                                                      | 1/8 [11:30<1:20:33, 690.49s/it]
# Wrapping the env in a DummyVecEnv.
# --------------------------------------
# | approxkl           | 0.00013842931 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0156       |
# | fps                | 355           |
# | n_updates          | 1             |
# | policy_entropy     | 1.0984852     |
# | policy_loss        | -0.0027446153 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 0.8094877     |
# --------------------------------------
#  25%|████████████████████▎                                                            | 2/8 [22:21<1:07:51, 678.58s/it]
# Wrapping the env in a DummyVecEnv.
# --------------------------------------
# | approxkl           | 0.0002140778  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00179      |
# | fps                | 356           |
# | n_updates          | 1             |
# | policy_entropy     | 1.0983894     |
# | policy_loss        | -0.0023990346 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 3.5817602     |
# --------------------------------------
#  38%|███████████████████████████████▏                                                   | 3/8 [33:02<55:36, 667.25s/it]
# Wrapping the env in a DummyVecEnv.
# --------------------------------------
# | approxkl           | 0.00023385261 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.13         |
# | fps                | 361           |
# | n_updates          | 1             |
# | policy_entropy     | 1.0983386     |
# | policy_loss        | -0.003294131  |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 0.035996456   |
# --------------------------------------
#  50%|█████████████████████████████████████████▌                                         | 4/8 [43:47<44:02, 660.73s/it]
# Wrapping the env in a DummyVecEnv.
# -------------------------------------
# | approxkl           | 0.0001194375 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.000148     |
# | fps                | 359          |
# | n_updates          | 1            |
# | policy_entropy     | 1.0984845    |
# | policy_loss        | -0.00396992  |
# | serial_timesteps   | 128          |
# | time_elapsed       | 0            |
# | total_timesteps    | 128          |
# | value_loss         | 10742.662    |
# -------------------------------------
#  62%|███████████████████████████████████████████████████▉                               | 5/8 [54:29<32:45, 655.04s/it]
# Wrapping the env in a DummyVecEnv.
# --------------------------------------
# | approxkl           | 3.508906e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000231     |
# | fps                | 357           |
# | n_updates          | 1             |
# | policy_entropy     | 1.0985737     |
# | policy_loss        | -0.0018958659 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 22338.79      |
# --------------------------------------
#  75%|████████████████████████████████████████████████████████████▊                    | 6/8 [1:05:03<21:37, 648.84s/it]
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------
# | approxkl           | 5.687502e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00645       |
# | fps                | 333            |
# | n_updates          | 1              |
# | policy_entropy     | 1.098556       |
# | policy_loss        | -0.00086774735 |
# | serial_timesteps   | 128            |
# | time_elapsed       | 0              |
# | total_timesteps    | 128            |
# | value_loss         | 59.170708      |
# ---------------------------------------
#  88%|██████████████████████████████████████████████████████████████████████▉          | 7/8 [1:15:32<10:42, 642.94s/it]
# Wrapping the env in a DummyVecEnv.
# --------------------------------------
# | approxkl           | 4.8427675e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000214     |
# | fps                | 349           |
# | n_updates          | 1             |
# | policy_entropy     | 1.0985602     |
# | policy_loss        | -0.0026338212 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 31161.363     |
# --------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████| 8/8 [1:26:18<00:00, 647.36s/it]

# %% [markdown]
# The model used is PPO2
#
# #### Short excerpt from docs:
# The Proximal Policy Optimization (PPO) algorithm combines ideas from A2C (having multiple workers) and TRPO (it uses a trust region to improve the actor).
#
# #### Link to doc:
# https://stable-baselines.readthedocs.io/en/master/modules/ppo2.html
#
# * there's other actor-critic based models to implement as well
