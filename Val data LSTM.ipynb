# %%
#requires tensorflow2
import tensorflow as tf
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import keras
import numpy as np
from ads_utils import load_data, plot, Environment

# %%
INITIAL_BALANCE = 10_000
PAST_TICKS = 5

# %%
answers = [INITIAL_BALANCE]
actions = []
portfolio_values = [INITIAL_BALANCE]
balance = INITIAL_BALANCE
prices = []
transaction_cost = 0.001

# %%
for i in range(6):
    data = load_data([i for i in range(12-i,12-i+4)])
    dataset = np.reshape(data['close'].values,(-1,1))
    scaled_dataset = dataset
    train= scaled_dataset[:int(scaled_dataset.shape[0]*0.75)]
    valid = scaled_dataset[int(scaled_dataset.shape[0]*0.75)-60:]
    from sklearn.preprocessing import MinMaxScaler
    sc = MinMaxScaler(feature_range = (0, 1))
    train2 = sc.fit_transform(train)
    valid2 = sc.transform(valid)
    x_train,y_train,x_test,y_test = [],[],[],[]
    for j in range(60,train2.shape[0]):
        x_train.append(train2[j-60:j,0])
        y_train.append(train2[j,0])
    for z in range(60,valid2.shape[0]):
        x_test.append(valid2[z-60:z,0])
        y_test.append(valid2[z,0])
    x_train, y_train,x_test,y_test = np.array(x_train), np.array(y_train),np.array(x_test),np.array(y_test)
    x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
    x_test=np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
    from keras.models import Sequential
    from keras.layers import Dense, Dropout,LSTM
    from keras.optimizers import Adam
    model = Sequential()
    model.add(LSTM(units=100,input_shape=(x_train.shape[1],1),return_sequences=True))
    model.add(LSTM(units=100))
    model.add(Dropout(0.4))
    model.add(Dense(1))
    ADAM = Adam(0.00001, beta_1=0.9, beta_2=0.999, amsgrad=False)
    model.compile(loss='mean_squared_error', optimizer=ADAM)
    history = model.fit(x_train,y_train,epochs=20,batch_size=72,validation_data=(x_test,y_test),verbose=1,shuffle=False)
    predicted_stock_price = sc.inverse_transform(model.predict(x_test))
    actual_stock_price = sc.inverse_transform(y_test.reshape((-1,1)))
    for j in range(len(actual_stock_price)):
        prices.append(actual_stock_price[j][0])
    for j in range(1,len(predicted_stock_price)):
        if predicted_stock_price[j]>actual_stock_price[j-1]:
            #go long
            balance += actual_stock_price[j]-actual_stock_price[j-1]
            actions.append(2)
        else:
            #go short
            balance += actual_stock_price[j-1]-actual_stock_price[j]
            actions.append(0)
        portfolio_values.append(float(balance))
    plot(prices=prices,target_positions = actions,portfolio_values = portfolio_values)
# Out:
# Epoch 1/20
# 428/428 [==============================] - 43s 101ms/step - loss: 0.2274 - val_loss: 0.0117
# Epoch 2/20
# 428/428 [==============================] - 43s 99ms/step - loss: 0.0373 - val_loss: 0.0019
# Epoch 3/20
# 428/428 [==============================] - 38s 89ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 4/20
# 428/428 [==============================] - 38s 90ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 5/20
# 428/428 [==============================] - 41s 95ms/step - loss: 0.0052 - val_loss: 8.5220e-04
# Epoch 6/20
# 428/428 [==============================] - 38s 89ms/step - loss: 0.0046 - val_loss: 6.7613e-04
# Epoch 7/20
# 428/428 [==============================] - 40s 94ms/step - loss: 0.0042 - val_loss: 5.5610e-04
# Epoch 8/20
# 428/428 [==============================] - 38s 89ms/step - loss: 0.0037 - val_loss: 4.8518e-04
# Epoch 9/20
# 428/428 [==============================] - 44s 102ms/step - loss: 0.0033 - val_loss: 4.3297e-04
# Epoch 10/20
# 428/428 [==============================] - 49s 114ms/step - loss: 0.0031 - val_loss: 4.0085e-04
# Epoch 11/20
# 428/428 [==============================] - 40s 93ms/step - loss: 0.0029 - val_loss: 3.6980e-04
# Epoch 12/20
# 428/428 [==============================] - 40s 94ms/step - loss: 0.0028 - val_loss: 3.5899e-04
# Epoch 13/20
# 428/428 [==============================] - 41s 96ms/step - loss: 0.0026 - val_loss: 3.3980e-04
# Epoch 14/20
# 428/428 [==============================] - 39s 92ms/step - loss: 0.0026 - val_loss: 3.3287e-04
# Epoch 15/20
# 428/428 [==============================] - 40s 94ms/step - loss: 0.0025 - val_loss: 3.3682e-04
# Epoch 16/20
# 428/428 [==============================] - 41s 95ms/step - loss: 0.0024 - val_loss: 3.3562e-04
# Epoch 17/20
# 428/428 [==============================] - 40s 93ms/step - loss: 0.0024 - val_loss: 3.2980e-04
# Epoch 18/20
# 428/428 [==============================] - 40s 93ms/step - loss: 0.0023 - val_loss: 3.2586e-04
# Epoch 19/20
# 428/428 [==============================] - 39s 92ms/step - loss: 0.0023 - val_loss: 3.1380e-04
# Epoch 20/20
# 428/428 [==============================] - 38s 89ms/step - loss: 0.0022 - val_loss: 3.2580e-04
# Epoch 1/20
# 407/407 [==============================] - 39s 95ms/step - loss: 0.2329 - val_loss: 0.0029
# Epoch 2/20
# 407/407 [==============================] - 38s 92ms/step - loss: 0.0099 - val_loss: 3.3607e-04
# Epoch 3/20
# 407/407 [==============================] - 36s 87ms/step - loss: 0.0084 - val_loss: 2.8573e-04
# Epoch 4/20
# 407/407 [==============================] - 38s 92ms/step - loss: 0.0072 - val_loss: 2.8132e-04
# Epoch 5/20
# 407/407 [==============================] - 37s 92ms/step - loss: 0.0063 - val_loss: 1.9271e-04
# Epoch 6/20
# 407/407 [==============================] - 38s 92ms/step - loss: 0.0059 - val_loss: 1.8376e-04
# Epoch 7/20
# 407/407 [==============================] - 36s 88ms/step - loss: 0.0054 - val_loss: 1.4766e-04
# Epoch 8/20
# 407/407 [==============================] - 39s 96ms/step - loss: 0.0049 - val_loss: 1.2406e-04
# Epoch 9/20
# 407/407 [==============================] - 38s 92ms/step - loss: 0.0048 - val_loss: 1.2825e-04
# Epoch 10/20
# 407/407 [==============================] - 36s 89ms/step - loss: 0.0044 - val_loss: 1.2770e-04
# Epoch 11/20
# 407/407 [==============================] - 38s 94ms/step - loss: 0.0044 - val_loss: 1.1607e-04
# Epoch 12/20
# 407/407 [==============================] - 39s 95ms/step - loss: 0.0042 - val_loss: 1.2600e-04
# Epoch 13/20
# 407/407 [==============================] - 37s 91ms/step - loss: 0.0041 - val_loss: 1.1293e-04
# Epoch 14/20
# 407/407 [==============================] - 38s 92ms/step - loss: 0.0040 - val_loss: 1.1501e-04
# Epoch 15/20
# 407/407 [==============================] - 38s 93ms/step - loss: 0.0040 - val_loss: 1.2531e-04
# Epoch 16/20
# 407/407 [==============================] - 36s 89ms/step - loss: 0.0039 - val_loss: 1.0597e-04
# Epoch 17/20
# 407/407 [==============================] - 37s 90ms/step - loss: 0.0038 - val_loss: 1.1301e-04
# Epoch 18/20
# 407/407 [==============================] - 38s 93ms/step - loss: 0.0038 - val_loss: 1.0573e-04
# Epoch 19/20
# 407/407 [==============================] - 35s 86ms/step - loss: 0.0037 - val_loss: 1.2026e-04
# Epoch 20/20
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0036 - val_loss: 1.1383e-04
# Epoch 1/20
# 393/393 [==============================] - 35s 90ms/step - loss: 0.1568 - val_loss: 0.0018
# Epoch 2/20
# 393/393 [==============================] - 34s 87ms/step - loss: 0.0086 - val_loss: 7.8762e-04
# Epoch 3/20
# 393/393 [==============================] - 35s 89ms/step - loss: 0.0077 - val_loss: 7.3006e-04
# Epoch 4/20
# 393/393 [==============================] - 38s 97ms/step - loss: 0.0069 - val_loss: 3.8083e-04
# Epoch 5/20
# 393/393 [==============================] - 37s 95ms/step - loss: 0.0062 - val_loss: 3.9513e-04
# Epoch 6/20
# 393/393 [==============================] - 35s 88ms/step - loss: 0.0057 - val_loss: 5.0694e-04
# Epoch 7/20
# 393/393 [==============================] - 36s 91ms/step - loss: 0.0053 - val_loss: 5.7841e-04
# Epoch 8/20
# 393/393 [==============================] - 35s 88ms/step - loss: 0.0049 - val_loss: 4.2686e-04
# Epoch 9/20
# 393/393 [==============================] - 36s 91ms/step - loss: 0.0046 - val_loss: 5.2277e-04
# Epoch 10/20
# 393/393 [==============================] - 37s 94ms/step - loss: 0.0045 - val_loss: 4.6464e-04
# Epoch 11/20
# 393/393 [==============================] - 34s 87ms/step - loss: 0.0043 - val_loss: 3.7383e-04
# Epoch 12/20
# 393/393 [==============================] - 36s 91ms/step - loss: 0.0041 - val_loss: 4.5273e-04
# Epoch 13/20
# 393/393 [==============================] - 35s 90ms/step - loss: 0.0040 - val_loss: 7.5227e-04
# Epoch 14/20
# 393/393 [==============================] - 37s 95ms/step - loss: 0.0039 - val_loss: 6.6935e-04
# Epoch 15/20
# 393/393 [==============================] - 39s 98ms/step - loss: 0.0039 - val_loss: 4.4842e-04
# Epoch 16/20
# 393/393 [==============================] - 37s 93ms/step - loss: 0.0038 - val_loss: 7.4042e-04
# Epoch 17/20
# 393/393 [==============================] - 35s 90ms/step - loss: 0.0037 - val_loss: 4.9379e-04
# Epoch 18/20
# 393/393 [==============================] - 36s 93ms/step - loss: 0.0036 - val_loss: 6.3253e-04
# Epoch 19/20
# 393/393 [==============================] - 34s 87ms/step - loss: 0.0035 - val_loss: 5.9993e-04
# Epoch 20/20
# 393/393 [==============================] - 35s 89ms/step - loss: 0.0035 - val_loss: 7.9960e-04
# Epoch 1/20
# 389/389 [==============================] - 39s 100ms/step - loss: 0.0932 - val_loss: 0.0029
# Epoch 2/20
# 389/389 [==============================] - 39s 100ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 3/20
# 389/389 [==============================] - 37s 94ms/step - loss: 0.0054 - val_loss: 0.0014
# Epoch 4/20
# 389/389 [==============================] - 41s 105ms/step - loss: 0.0049 - val_loss: 8.6690e-04
# Epoch 5/20
# 389/389 [==============================] - 40s 102ms/step - loss: 0.0043 - val_loss: 7.7967e-04
# Epoch 6/20
# 389/389 [==============================] - 38s 98ms/step - loss: 0.0040 - val_loss: 8.2156e-04
# Epoch 7/20
# 389/389 [==============================] - 38s 97ms/step - loss: 0.0037 - val_loss: 8.7123e-04
# Epoch 8/20
# 389/389 [==============================] - 37s 96ms/step - loss: 0.0035 - val_loss: 8.8289e-04
# Epoch 9/20
# 389/389 [==============================] - 38s 99ms/step - loss: 0.0032 - val_loss: 7.9414e-04
# Epoch 10/20
# 389/389 [==============================] - 38s 97ms/step - loss: 0.0031 - val_loss: 7.0419e-04
# Epoch 11/20
# 389/389 [==============================] - 36s 93ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 12/20
# 389/389 [==============================] - 35s 90ms/step - loss: 0.0028 - val_loss: 6.7052e-04
# Epoch 13/20
# 389/389 [==============================] - 36s 93ms/step - loss: 0.0029 - val_loss: 9.7097e-04
# Epoch 14/20
# 389/389 [==============================] - 42s 109ms/step - loss: 0.0028 - val_loss: 7.6400e-04
# Epoch 15/20
# 389/389 [==============================] - 36s 93ms/step - loss: 0.0027 - val_loss: 7.3248e-04
# Epoch 16/20
# 389/389 [==============================] - 36s 94ms/step - loss: 0.0026 - val_loss: 9.1050e-04
# Epoch 17/20
# 389/389 [==============================] - 39s 101ms/step - loss: 0.0026 - val_loss: 8.2486e-04
# Epoch 18/20
# 389/389 [==============================] - 39s 101ms/step - loss: 0.0025 - val_loss: 7.7891e-04
# Epoch 19/20
# 389/389 [==============================] - 37s 96ms/step - loss: 0.0025 - val_loss: 8.9311e-04
# Epoch 20/20
# 389/389 [==============================] - 36s 93ms/step - loss: 0.0025 - val_loss: 5.9886e-04
# Epoch 1/20
# 397/397 [==============================] - 43s 109ms/step - loss: 0.0163 - val_loss: 0.0012
# Epoch 2/20
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0040 - val_loss: 5.7953e-04
# Epoch 3/20
# 397/397 [==============================] - 42s 105ms/step - loss: 0.0029 - val_loss: 3.4876e-04
# Epoch 4/20
# 397/397 [==============================] - 39s 99ms/step - loss: 0.0023 - val_loss: 3.7914e-04
# Epoch 5/20
# 397/397 [==============================] - 41s 103ms/step - loss: 0.0019 - val_loss: 3.7889e-04
# Epoch 6/20
# 397/397 [==============================] - 42s 107ms/step - loss: 0.0017 - val_loss: 3.6561e-04
# Epoch 7/20
# 397/397 [==============================] - 41s 103ms/step - loss: 0.0016 - val_loss: 3.3418e-04
# Epoch 8/20
# 397/397 [==============================] - 42s 105ms/step - loss: 0.0015 - val_loss: 3.7204e-04
# Epoch 9/20
# 397/397 [==============================] - 42s 105ms/step - loss: 0.0014 - val_loss: 3.7087e-04
# Epoch 10/20
# 397/397 [==============================] - 40s 101ms/step - loss: 0.0013 - val_loss: 4.2679e-04
# Epoch 11/20
# 397/397 [==============================] - 40s 102ms/step - loss: 0.0013 - val_loss: 3.4124e-04
# Epoch 12/20
# 397/397 [==============================] - 40s 100ms/step - loss: 0.0012 - val_loss: 2.5674e-04
# Epoch 13/20
# 397/397 [==============================] - 40s 102ms/step - loss: 0.0012 - val_loss: 3.3190e-04
# Epoch 14/20
# 397/397 [==============================] - 41s 104ms/step - loss: 0.0011 - val_loss: 2.6795e-04
# Epoch 15/20
# 397/397 [==============================] - 54s 137ms/step - loss: 0.0011 - val_loss: 2.9884e-04
# Epoch 16/20
# 397/397 [==============================] - 42s 106ms/step - loss: 0.0011 - val_loss: 5.0536e-04
# Epoch 17/20
# 397/397 [==============================] - 40s 102ms/step - loss: 0.0010 - val_loss: 2.6392e-04
# Epoch 18/20
# 397/397 [==============================] - 40s 101ms/step - loss: 0.0010 - val_loss: 3.7704e-04
# Epoch 19/20
# 397/397 [==============================] - 41s 103ms/step - loss: 9.9426e-04 - val_loss: 4.9891e-04
# Epoch 20/20
# 397/397 [==============================] - 40s 101ms/step - loss: 9.7416e-04 - val_loss: 4.2960e-04
# Epoch 1/20
# 428/428 [==============================] - 43s 100ms/step - loss: 0.0095 - val_loss: 0.0021
# Epoch 2/20
# 428/428 [==============================] - 43s 100ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 3/20
# 428/428 [==============================] - 43s 101ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 4/20
# 428/428 [==============================] - 43s 101ms/step - loss: 0.0031 - val_loss: 8.4834e-04
# Epoch 5/20
# 428/428 [==============================] - 44s 103ms/step - loss: 0.0028 - val_loss: 7.5149e-04
# Epoch 6/20
# 428/428 [==============================] - 43s 100ms/step - loss: 0.0025 - val_loss: 7.4072e-04
# Epoch 7/20
# 428/428 [==============================] - 43s 101ms/step - loss: 0.0025 - val_loss: 6.8352e-04
# Epoch 8/20
# 428/428 [==============================] - 44s 102ms/step - loss: 0.0023 - val_loss: 6.6363e-04
# Epoch 9/20
# 428/428 [==============================] - 43s 100ms/step - loss: 0.0023 - val_loss: 6.5077e-04
# Epoch 10/20
# 428/428 [==============================] - 44s 102ms/step - loss: 0.0022 - val_loss: 6.9032e-04
# Epoch 11/20
# 428/428 [==============================] - 42s 99ms/step - loss: 0.0022 - val_loss: 6.5864e-04
# Epoch 12/20
# 428/428 [==============================] - 42s 99ms/step - loss: 0.0021 - val_loss: 6.9044e-04
# Epoch 13/20
# 428/428 [==============================] - 43s 100ms/step - loss: 0.0021 - val_loss: 6.5307e-04
# Epoch 14/20
# 428/428 [==============================] - 42s 99ms/step - loss: 0.0020 - val_loss: 6.3945e-04
# Epoch 15/20
# 428/428 [==============================] - 42s 98ms/step - loss: 0.0020 - val_loss: 6.4087e-04
# Epoch 16/20
# 428/428 [==============================] - 43s 100ms/step - loss: 0.0019 - val_loss: 6.2674e-04
# Epoch 17/20
# 428/428 [==============================] - 43s 102ms/step - loss: 0.0020 - val_loss: 6.1059e-04
# Epoch 18/20
# 428/428 [==============================] - 42s 98ms/step - loss: 0.0019 - val_loss: 6.1061e-04
# Epoch 19/20
# 428/428 [==============================] - 43s 100ms/step - loss: 0.0019 - val_loss: 6.1738e-04
# Epoch 20/20
# 428/428 [==============================] - 42s 99ms/step - loss: 0.0019 - val_loss: 6.0086e-04
